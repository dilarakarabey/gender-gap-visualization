# %% [markdown]
# # Visualization of Gender Gap in College Degrees
#
# ### The US Department of Education Statistics has released a data set containing the percentage of Bachelor's degrees granted to women from 1970 to 2011. The data set is broken up into 17 categories of degrees, with each column as a separate category.
#
# #### Randal Olson, a data scientist at University of Pennsylvania, has cleaned the data set and made it available on his personal website. This cleaned version of the data set will be used in this project.
#
# Randal Olson compiled this data set to explore the gender gap in STEM fields, which stands for Science, Technology, Engineering, and Mathematics. We will be visualizing gender gaps in all categories from all fields in this project.
#
# ##### Let's check out our data first:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %% [markdown]
# ##### As we can see, the data set is sorted by the "Year" column and includes percentage of female graduates per category.
#
# ##### Next: Let's create some exemplary line charts for the STEM Categories. We will be using the Color Blind 10 colour palette for accessibility.

# %%
cb_dark_blue = (0/255, 107/255, 164/255) #Representing women
cb_orange = (255/255, 128/255, 14/255) #Representing men

#"cats" below in variable names stands for "categories"
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(18, 21))
fig.suptitle("Percentage of Bachelor's Degrees Awarded By Gender\nBetween the Years of 1970-2011", fontsize=20)

for sp in range(0,6): #since there are 6 categories under the STEM field
    ax = fig.add_subplot(6,3,sp+1)
    
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100 - women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)

    #Let's not display the spines for simplicity's sake.
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    
    ax.set_xlim(1968, 2011) #Years
    ax.set_ylim(0,100) #Percentage
    
    ax.set_title(stem_cats[sp])
    
    ax.tick_params(bottom="on", top="off", left="on", right="off")

    #To better communicate the charts, let's label the lines. I prefer this over a legend because it takes less space.
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
plt.show()

# %% [markdown]
# ##### We see the line charts created for the STEM field categories above. As we can see, labels that indicate the years on the bottom of the charts make everything look a bit crowded.
# ##### Let's create line charts for all categories fixing this:

# %%
fig = plt.figure(figsize=(18, 21))
fig.suptitle("Percentage of Bachelor's Degrees Awarded By Gender\nBetween the Years of 1970-2011", fontsize=20)

#First column represents STEM categories:
for sp in range(0, 18, 3):
    index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[index])
    ax.tick_params(bottom="on", top="off", left="on", right="off", labelbottom="off")
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if index == 0:
        ax.text(2005, 92, 'Men')
        ax.text(2005, 6, 'Women')
    elif index == 5:
        ax.text(2005, 63, 'Men')
        ax.text(2005, 33, 'Women')
        ax.tick_params(labelbottom="on")

#Second column represents Liberal Arts categories:
for sp in range(1, 16, 3): #0, 15 >>> +1 >>> 1, 16 due to column position
    index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if index == 0:
        ax.text(2005, 17, 'Men')
        ax.text(2005, 82, 'Women')
    elif index == 4:
        ax.tick_params(labelbottom="on")

#Third column represents other categories:
for sp in range(2, 20, 3):
    index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[index]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[index]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[index])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    ax.set_yticks([0, 100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if index == 0:
        ax.text(2005, 6, "Men")
        ax.text(2005, 90, "Women")
    elif index == 5:
        ax.text(2005, 65, "Men")
        ax.text(2005, 30, "Women")
        ax.tick_params(labelbottom="on")

# %% [markdown]
# ##### Nice! Now, let's see if we can export these:

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %% [markdown]
# ##### Finally, Run this to export the plots into a single png file:

# %%
plt.savefig("degrees_gender_gaps.png")
